# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('../data/cifar10/cifar10_sgd_deep_model.csv')
df.head()
# Out:
#        loss  accuracy  val_loss  val_accuracy
# 0  2.093257   0.21430  1.766047         0.368
# 1  1.725333   0.35890  1.484398         0.467
# 2  1.572578   0.42278  1.380100         0.518
# 3  1.461439   0.47194  1.276165         0.557
# 4  1.356248   0.51452  1.203942         0.579

# %%
df['epoch'] = df.index

# %%
df.plot(x='epoch', y=['loss', 'val_loss'])

# %%
df.plot(x='epoch', y=['accuracy', 'val_accuracy'])

# %%
import tally_predictions
import roc_curve_area
